# %%
import math
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

from scipy.optimize import curve_fit

from pathlib import Path

# %%
from packaging.version import Version
if Version(matplotlib.__version__) > Version('3.7.0'):
    raise RuntimeWarning('tikzplotlib cant work with matplotlib > 3.7')

import tikzplotlib
def tikzplotlib_fix_ncols(obj):
    """
    workaround for matplotlib 3.6 renamed legend's _ncol to _ncols, which breaks tikzplotlib
    """
    if hasattr(obj, "_ncols"):
        obj._ncol = obj._ncols
    for child in obj.get_children():
        tikzplotlib_fix_ncols(child)

# %%
ROOT_PATH = Path('./..')

LATEX_PATH = ROOT_PATH / 'paper'

RESOURCES_PATH = ROOT_PATH / 'resources'

CPP_BUILD_PATH = ROOT_PATH / 'build'

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, figsize=(10, 10))
x = [3, 5, 7, 10, 12, 15]

ax1.plot(x, [0.05, 0.175, 0.180, 0.215, 0.275, 0.375], marker='o', label='без демпфирования')
ax1.plot(x, [0.01, 0.110, 0.115, 0.105, 0.105, 0.100], marker='^', label='с демпфированием')
ax1.set_ylabel('Вертикальная перегрузка перегрузка')
ax1.set_ylim(0, 0.4)
ax1.set_xlim(0, 16)
ax1.set_yticklabels([str(round(float(t.get_text()), 2)) + "g" for t in ax1.get_yticklabels()])
ax1.grid(True)

ax2.plot(x, [0, 0.02, 0.025, 0.06, 0.1, 0.19], marker='o', label='без демпфирования')
ax2.plot(x, [0, 0.018, 0.019, 0.05, 0.065, 0.06], marker='^', label='с демпфированием')
ax2.set_ylabel('Размах вертикальной качки [м]')
ax2.set_ylim(0, 0.2)
ax2.grid(True)
ax2.legend(loc='upper left')

ax3.plot(x, [0, 0.8, 1.4, 3.5, 5.6, 5], marker='o', label='без демпфирования')
ax3.plot(x, [0, 0.6, 0.6, 1.2, 1.4, 1.4], marker='^', label='с демпфированием')
ax3.set_ylabel('Тангаж [phi, °]')
ax3.set_xlabel('Длина волны [м]')
ax3.set_ylim(0, 6)
ax3.grid(True)

plt.plot();
# tikzplotlib_fix_ncols(fig)
# tikzplotlib.save(LATEX_PATH / 'graph5_tikz.tex')
# Out:
# /tmp/ipykernel_32094/3582216169.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels([str(round(float(t.get_text()), 2)) + "g" for t in ax1.get_yticklabels()])

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, figsize=(10, 10))
x = [3, 5, 7, 10, 12, 15]

ax1.plot(x, [0.04, 0.275, 0.260, 0.355, 0.350, 0.360], marker='o', label='без демпфирования')
ax1.plot(x, [0.02, 0.175, 0.130, 0.130, 0.150, 0.150], marker='^', label='с демпфированием')
ax1.set_ylabel('Вертикальная перегрузка перегрузка')
ax1.set_ylim(0, 0.4)
ax1.set_xlim(0, 16)
ax1.set_yticklabels([str(round(float(t.get_text()), 2)) + "g" for t in ax1.get_yticklabels()])
ax1.grid(True)

ax2.plot(x, [0, 0.01, 0.02, 0.04, 0.05, 0.085], marker='o', label='без демпфирования')
ax2.plot(x, [0, 0.005, 0.01, 0.015, 0.029, 0.05], marker='^', label='с демпфированием')
ax2.set_ylabel('Размах вертикальной качки [м]')
ax2.set_ylim(0, 0.2)
ax2.grid(True)
ax2.legend(loc='upper left')

ax3.plot(x, [0, 0.4, 0.5, 1.5, 2.5, 4], marker='o', label='без демпфирования')
ax3.plot(x, [0, 0.35, 0.5, 0.9, 1, 1.2], marker='^', label='с демпфированием')
ax3.set_ylabel('Тангаж [phi, °]')
ax3.set_xlabel('Длина волны [м]')
ax3.set_ylim(0, 6)
ax3.grid(True)

plt.plot();
# tikzplotlib_fix_ncols(fig)
# tikzplotlib.save(LATEX_PATH / 'graph6_tikz.tex')
# Out:
# /tmp/ipykernel_32094/1001580244.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels([str(round(float(t.get_text()), 2)) + "g" for t in ax1.get_yticklabels()])
